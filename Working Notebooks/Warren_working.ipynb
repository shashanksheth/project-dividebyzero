# %%
# Dependencies
import csv, os #>, requests, json, pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Read CSV into Pandas DataFrame
olympics_df = pd.read_csv('olympics_df.csv')

olympics_df.tail()
# Out:
#                             Name Sex   Age  Height  Weight  NOC       Region  \
# 271111  Luis Fernando Lpez Erazo   M  37.0   166.0    60.0  COL     Colombia
# 271112          Enrico D'Aniello   M  20.0   152.0    53.0  ITA        Italy
# 271113          Sabrina D'Angelo   F  23.0   173.0    71.0  CAN       Canada
# 271114  Andrea Mitchell D'Arrigo   M  21.0   194.0    85.0  ITA        Italy
# 271115             Blair Tarrant   M  26.0   185.0    83.0  NZL  New Zealand
#
#          Medal      Sport                                Event  Year  Season  \
# 271111     NaN  Athletics   Athletics Men's 20 kilometres Walk  2016  Summer
# 271112     NaN     Rowing            Rowing Men's Coxed Eights  2016  Summer
# 271113  Bronze   Football            Football Women's Football  2016  Summer
# 271114     NaN   Swimming  Swimming Men's 200 metres Freestyle  2016  Summer
# 271115     NaN     Hockey                  Hockey Men's Hockey  2016  Summer
#
#                   City
# 271111  Rio de Janeiro
# 271112  Rio de Janeiro
# 271113  Rio de Janeiro
# 271114  Rio de Janeiro
# 271115  Rio de Janeiro

# %%
olympics_df.count()
# Out:
# Name      271116
# Sex       271116
# Age       261642
# Height    210945
# Weight    208241
# NOC       271116
# Region    270746
# Medal      39783
# Sport     271116
# Event     271116
# Year      271116
# Season    271116
# City      271116
# dtype: int64

# %% [markdown]
# ---
# ## Number of events an athlete has participated in

# %%
olympics_groupedby_ID = olympics_df.groupby('Name')

event_count = olympics_groupedby_ID.count()['Sex'].sort_values(ascending=False)

event_count.head()
# Out:
# Name
# Robert Tait McKenzie        58
# Heikki Ilmari Savolainen    39
# Joseph "Josy" Stoffel       38
# Ioannis Theofilakis         36
# Takashi Ono                 33
# Name: Sex, dtype: int64

# %%
plt.figure(0,(10,5))
plt.hist(event_count, bins=50, log=True, rwidth=0.5)
plt.xlabel("Number of Events")
plt.ylabel("Athlete Count")
plt.show()

# %%
quartiles = event_count.quantile([0.25,0.5,0.75])
lowerq = quartiles[0.25]
median_temp = quartiles[0.5]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Event Count is: {lowerq}")
print(f"The upper quartile of Event Count is: {upperq}")
print(f"The interquartile range of Event Count is: {iqr}")
print(f"The the median of Event Count is: {median_temp} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
#> print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Event Count is: 1.0
# The upper quartile of Event Count is: 2.0
# The interquartile range of Event Count is: 1.0
# The the median of Event Count is: 1.0
# Values above 3.5 could be outliers.

# %% [markdown]
# ## Number of events an athlete *who has medalled* has participated in

# %%
olympics_groupedby_ID_df = pd.DataFrame(olympics_groupedby_ID.count())

# %%
medalled_olymians_df = olympics_groupedby_ID_df.loc[olympics_groupedby_ID_df['Medal'] > 0]

# %%
medalled_groupedby_ID = medalled_olymians_df.groupby('Name')

medalled_event_count = medalled_groupedby_ID.max()['Sex'].sort_values(ascending=False)

medalled_event_count.head()
# Out:
# Name
# Robert Tait McKenzie                58
# Heikki Ilmari Savolainen            39
# Ioannis Theofilakis                 36
# Takashi Ono                         33
# Alfrd (Arnold-) Hajs (Guttmann-)    32
# Name: Sex, dtype: int64

# %%
plt.figure(0,(10,5))
plt.hist(medalled_event_count, bins=50, log=True, rwidth=0.5)
plt.xlabel("Number of Events")
plt.ylabel("Athlete Count")
plt.show()

# %%
quartiles = medalled_event_count.quantile([0.25,0.5,0.75])
lowerq = quartiles[0.25]
median_temp = quartiles[0.5]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Event Count is: {lowerq}")
print(f"The upper quartile of Event Count is: {upperq}")
print(f"The interquartile range of Event Count is: {iqr}")
print(f"The the median of Event Count is: {median_temp} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
#> print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Event Count is: 1.0
# The upper quartile of Event Count is: 3.0
# The interquartile range of Event Count is: 2.0
# The the median of Event Count is: 2.0
# Values above 6.0 could be outliers.

# %%
plt.figure(0,(5,10))
plt.title('Number of events an Athlete has competed in')
plt.ylabel('Athlete Count')
plt.boxplot([medalled_event_count, event_count])
plt.xticks([1,2],['Medalled', 'All'])

# Here we see someone who competed in 38 events yet never once medalled
plt.annotate('Never medalled -->',(1.25,37.75),fontsize=10,color="red")
plt.show()

# %% [markdown]
# #### So who is Joseph "Josy" Stoffel?
# * Born on June 27th, 1928 (currently age 91) he went to 5 Summer Olympic games between 1948 to 1964.  From age 20 to 36 he competed on behalf of Luxembourg in 7-8 Gymnastics events per trip. Unfortunately he did not finish within the top three in any of his 38 competitions. But not for nothing, Stoffel dominated the domestic scene, and won the Luxembourgian national gymnastics championships for sixteen straight years, from 1949 until 1964.
#
# ## *Calculate the chances of winning a metal if you attend the olympics, then see what Josy's chances were.*
# ---

# %% [markdown]
# ## Female Medal Count vs Women's Freedom

# %%
# Read CSV into Pandas DataFrame
raw_WPS_df = pd.read_csv('raw_data/WPS_Index_Raw_Data.csv')
WPS_df = raw_WPS_df[[
 'WPS Index rank',
 'Country and group',
 'WPS Index value']]
WPS_df = WPS_df.rename(columns={'Country and group': 'Region'})
WPS_df.head()
# Out:
#    WPS Index rank       Region  WPS Index value
# 0               1       Norway            0.904
# 1               2  Switzerland            0.893
# 2               3      Finland            0.891
# 3               3      Denmark            0.891
# 4               5      Iceland            0.888

# %%
WPS_df = WPS_df.dropna(how='all')
WPS_df.head(20)
# Out:
#     WPS Index rank                    Region  WPS Index value
# 0                1                    Norway            0.904
# 1                2               Switzerland            0.893
# 2                3                   Finland            0.891
# 3                3                   Denmark            0.891
# 4                5                   Iceland            0.888
# 5                6                   Austria            0.884
# 6                7            United Kingdom            0.883
# 7                8                Luxembourg            0.880
# 8                9                    Sweden            0.879
# 9                9               Netherlands            0.879
# 10              11                    Canada            0.876
# 11              12                   Estonia            0.873
# 12              13                  Slovenia            0.872
# 13              14               New Zealand            0.869
# 14              15                     Spain            0.860
# 15              16                   Ireland            0.858
# 16              17                   Germany            0.856
# 17              17                  Portugal            0.856
# 18              19  United States of America            0.851
# 19              20                    France            0.847

# %% [markdown]
# #### Now we start working on the Olympics DF

# %%
slim_olympics_df = olympics_df.drop(['Height', 'Weight', 'City'],1)

# %%
recent_olympics_df = slim_olympics_df.loc[olympics_df.Year >= 2014]

# %%
recent_olympics_WPS_df = pd.merge(recent_olympics_df, WPS_df, on='Region', how='left')
recent_olympics_WPS_df.count()
# Out:
# Name               18579
# Sex                18579
# Age                18579
# NOC                18579
# Region             18534
# Medal               2620
# Sport              18579
# Event              18579
# Year               18579
# Season             18579
# WPS Index rank     17760
# WPS Index value    17760
# dtype: int64

# %%
medalled_recent_WPS_df = recent_olympics_WPS_df.loc[
    (recent_olympics_WPS_df.Medal == 'Bronze') | 
    (recent_olympics_WPS_df.Medal == 'Silver') | 
    (recent_olympics_WPS_df.Medal == 'Gold')]

medalled_recent_WPS_df.count()
# Out:
# Name               2620
# Sex                2620
# Age                2620
# NOC                2620
# Region             2619
# Medal              2620
# Sport              2620
# Event              2620
# Year               2620
# Season             2620
# WPS Index rank     2578
# WPS Index value    2578
# dtype: int64

# %%
print("Unfortunately the following countries don't have WPS scores:")
list(medalled_recent_WPS_df.loc[
    medalled_recent_WPS_df['WPS Index rank'].isnull() == True].Region.unique())
# Out:
# Unfortunately the following countries don't have WPS scores:
# ['Venezuela',
#  'Cuba',
#  'North Korea',
#  'Bahamas',
#  'Kosovo',
#  'Vietnam',
#  'Individual Olympic Athletes',
#  'Taiwan',
#  nan,
#  'Ivory Coast',
#  'Grenada',
#  'Puerto Rico']

# %%
print(f"Thankfully they only account for {round(100*(medalled_recent_WPS_df.Name.count()-medalled_recent_WPS_df['WPS Index rank'].count())/medalled_recent_WPS_df.Name.count(),1)}% of the medals")
# Out:
# Thankfully they only account for 1.6% of the medals

# %%
medalled_recent_WPS_df = medalled_recent_WPS_df.dropna()

medalled_recent_WPS_df.count() #2578
# Out:
# Name               2578
# Sex                2578
# Age                2578
# NOC                2578
# Region             2578
# Medal              2578
# Sport              2578
# Event              2578
# Year               2578
# Season             2578
# WPS Index rank     2578
# WPS Index value    2578
# dtype: int64

# %%
plt.figure(0,(10,5))
plt.hist(medalled_recent_WPS_df['WPS Index value'], bins=10, rwidth=0.5)
plt.xlabel("WPS Index Value")
plt.ylabel("Medal Count")
plt.show()

# %%
female_medalled_recent_WPS_df = medalled_recent_WPS_df.loc[
    medalled_recent_WPS_df.Sex == 'F']
male_medalled_recent_WPS_df = medalled_recent_WPS_df.loc[
    medalled_recent_WPS_df.Sex == 'M']

# %%
plt.figure(0,(10,5))
plt.hist([male_medalled_recent_WPS_df['WPS Index value'], 
          female_medalled_recent_WPS_df['WPS Index value']], 
         label=['Men', 'Women'], bins=9, rwidth=0.5)
plt.xlabel("WPS Index Value")
plt.ylabel("Medal Count")
plt.legend()
plt.show()

# %% [markdown]
# ### This histogram shows that countries in the 90th percentile of women's freedom see their female athletes bring home more metals than their male athletes.
# ---

# %%
female_medalled_groupedby_region = female_medalled_recent_WPS_df.groupby('Region')
male_medalled_groupedby_region = male_medalled_recent_WPS_df.groupby('Region')

gender_medalled_df = pd.merge(
    female_medalled_groupedby_region.Medal.count(), 
    male_medalled_groupedby_region.Medal.count(), 
    on='Region', how='outer', suffixes=['_Females', '_Males'])

gender_medalled_df = gender_medalled_df.fillna(0)

gender_medalled_df['Medal_Total'] = gender_medalled_df.Medal_Males + gender_medalled_df.Medal_Females

gender_medalled_df
# Out:
#                       Medal_Females  Medal_Males  Medal_Total
# Region
# Argentina                       2.0         20.0         22.0
# Australia                      41.0         44.0         85.0
# Austria                         9.0         20.0         29.0
# Azerbaijan                      4.0         14.0         18.0
# Bahrain                         2.0          0.0          2.0
# ...                             ...          ...          ...
# Qatar                           0.0          1.0          1.0
# Tajikistan                      0.0          1.0          1.0
# Trinidad                        0.0          1.0          1.0
# United Arab Emirates            0.0          1.0          1.0
# Uzbekistan                      0.0         13.0         13.0
#
# [75 rows x 3 columns]

# %%
gender_medalled_df['Percent_Female'] = round(
    100*gender_medalled_df.Medal_Females / (gender_medalled_df.Medal_Males + gender_medalled_df.Medal_Females),2)

gender_medalled_df['Percent_Male'] = round(
    100*gender_medalled_df.Medal_Males / (gender_medalled_df.Medal_Males + gender_medalled_df.Medal_Females),2)

gender_medalled_df
# Out:
#                       Medal_Females  Medal_Males  Medal_Total  Percent_Female  \
# Region
# Argentina                       2.0         20.0         22.0            9.09
# Australia                      41.0         44.0         85.0           48.24
# Austria                         9.0         20.0         29.0           31.03
# Azerbaijan                      4.0         14.0         18.0           22.22
# Bahrain                         2.0          0.0          2.0          100.00
# ...                             ...          ...          ...             ...
# Qatar                           0.0          1.0          1.0            0.00
# Tajikistan                      0.0          1.0          1.0            0.00
# Trinidad                        0.0          1.0          1.0            0.00
# United Arab Emirates            0.0          1.0          1.0            0.00
# Uzbekistan                      0.0         13.0         13.0            0.00
#
#                       Percent_Male
# Region
# Argentina                    90.91
# Australia                    51.76
# Austria                      68.97
# Azerbaijan                   77.78
# Bahrain                       0.00
# ...                            ...
# Qatar                       100.00
# Tajikistan                  100.00
# Trinidad                    100.00
# United Arab Emirates        100.00
# Uzbekistan                  100.00
#
# [75 rows x 5 columns]

# %%
gender_medalled_df = pd.merge(gender_medalled_df, WPS_df, 
                              on='Region', how='left')
gender_medalled_df
# Out:
#                   Region  Medal_Females  Medal_Males  Medal_Total  \
# 0              Argentina            2.0         20.0         22.0
# 1              Australia           41.0         44.0         85.0
# 2                Austria            9.0         20.0         29.0
# 3             Azerbaijan            4.0         14.0         18.0
# 4                Bahrain            2.0          0.0          2.0
# ..                   ...            ...          ...          ...
# 70                 Qatar            0.0          1.0          1.0
# 71            Tajikistan            0.0          1.0          1.0
# 72              Trinidad            0.0          1.0          1.0
# 73  United Arab Emirates            0.0          1.0          1.0
# 74            Uzbekistan            0.0         13.0         13.0
#
#     Percent_Female  Percent_Male  WPS Index rank  WPS Index value
# 0             9.09         90.91              48            0.775
# 1            48.24         51.76              22            0.844
# 2            31.03         68.97               6            0.884
# 3            22.22         77.78             123            0.650
# 4           100.00          0.00              83            0.719
# ..             ...           ...             ...              ...
# 70            0.00        100.00              72            0.730
# 71            0.00        100.00              96            0.701
# 72            0.00        100.00              41            0.788
# 73            0.00        100.00              44            0.781
# 74            0.00        100.00              89            0.710
#
# [75 rows x 8 columns]

# %%
x_values = gender_medalled_df['WPS Index value']
y_values = gender_medalled_df['Percent_Female']
z_values = gender_medalled_df['Medal_Total']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, s=z_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(.55,40),fontsize=10,color="red")
plt.ylabel('Percent of Medals by Women')
plt.xlabel('WPS Value')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0169784838781401

# %%
coefficient = stats.pearsonr(
    gender_medalled_df['WPS Index value'],gender_medalled_df['Percent_Female'])[0]
pvalue = stats.pearsonr(
    gender_medalled_df['WPS Index value'],gender_medalled_df['Percent_Female'])[1]

print(f"The correlation is {round(coefficient,4)} and the p-value is {pvalue}")
# Out:
# The correlation is 0.1303 and the p-value is 0.26517227530555165

# %%
x_values = gender_medalled_df['WPS Index value']
y_values = gender_medalled_df['Percent_Female']*(
    (gender_medalled_df.Medal_Males + gender_medalled_df.Medal_Females)
    /(gender_medalled_df.Medal_Males.sum() + gender_medalled_df.Medal_Females.sum()))
z_values = gender_medalled_df['Medal_Total']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(0,(10,5))
plt.scatter(x_values, y_values, s=z_values, edgecolor='steelblue', alpha=.6)
plt.plot(x_values,regress_values,"r-",lw=.2)
plt.annotate(line_eq,(.71,.7),fontsize=12,color="red", rotation=5)
plt.annotate('USA -->',(.81,7.1),fontsize=12,color="steelblue")
plt.annotate('Russia -->',(.72,4.0),fontsize=12,color="steelblue")
plt.annotate('Canada -->',(.82,3.8),fontsize=12,color="steelblue")
plt.annotate('Germany -->',(.79,3.0),fontsize=12,color="steelblue")
plt.annotate('China -->',(.68,2.9),fontsize=12,color="steelblue")
plt.title('Percent of All Medals Won by Females per Country versus WPS Index')
plt.xlabel('WPS Index Value (out of 1.00)')
plt.ylabel('Percent of Medals (%)')
plt.ylim(-1,10)
print(f"The correlation value (r) is: {rvalue}")
plt.show()
# Out:
# The correlation value (r) is: 0.37028102273850627

# %%
coefficient = stats.pearsonr(
    gender_medalled_df['WPS Index value'],y_values)[0]
pvalue = stats.pearsonr(
    gender_medalled_df['WPS Index value'],y_values)[1]

print(f"The correlation is {round(coefficient,4)} and the p-value is {pvalue}")
# Out:
# The correlation is 0.3703 and the p-value is 0.0010757485921077444

# %%
# This was just to find the top 5 countries and label them
gender_medalled_df.sort_values('Medal_Females', ascending=False)
# Out:
#                       Region  Medal_Females  Medal_Males  Medal_Total  \
# 59  United States of America          188.0        140.0        328.0
# 45                    Russia          105.0         78.0        183.0
# 10                    Canada          101.0         54.0        155.0
# 20                   Germany           82.0        113.0        195.0
# 11                     China           80.0         45.0        125.0
# ..                       ...            ...          ...          ...
# 64                      Fiji            0.0         13.0         13.0
# 62        Dominican Republic            0.0          1.0          1.0
# 61                   Armenia            0.0          4.0          4.0
# 60                   Algeria            0.0          2.0          2.0
# 74                Uzbekistan            0.0         13.0         13.0
#
#     Percent_Female  Percent_Male  WPS Index rank  WPS Index value
# 59           57.32         42.68              19            0.851
# 45           57.38         42.62              51            0.770
# 10           65.16         34.84              11            0.876
# 20           42.05         57.95              17            0.856
# 11           64.00         36.00              76            0.725
# ..             ...           ...             ...              ...
# 64            0.00        100.00              58            0.757
# 62            0.00        100.00              74            0.726
# 61            0.00        100.00              82            0.720
# 60            0.00        100.00             143            0.611
# 74            0.00        100.00              89            0.710
#
# [75 rows x 8 columns]

# %% [markdown]
# ## vs GDP per Capita

# %%
# Read CSV into Pandas DataFrame
GDPpC_df = pd.read_csv('raw_data/CLEAN-GDPPC-USD-countries.csv')

GDPpC_df.head()
# Out:
#    CountryID      Country   1990   1991   1992   1993   1994   1995   1996  \
# 0          4  Afghanistan    292    251    240    168    124    179    166
# 1          8      Albania    653    487    467    532    598    769   1033
# 2         12      Algeria   2397   1764   1817   1840   1500   1459   1600
# 3         20      Andorra  23886  24714  25999  20900  20542  23359  24064
# 4         24       Angola   1153   1321   1468   1030   1026    476    606
#
#     1997  ...   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0    156  ...    443    551    637    685    670    639    599    572    593
# 1    718  ...   4051   4046   4402   4228   4400   4567   3939   4109   4516
# 2   1616  ...   3883   4481   5456   5592   5500   5493   4178   3946   4044
# 3  23224  ...  43336  39734  41103  38393  40629  42299  36041  37223  39231
# 4    688  ...   3123   3588   4615   5100   5255   5408   4167   3506   4096
#
#     2018
# 0    552
# 1   5224
# 2   4115
# 3  42052
# 4   3437
#
# [5 rows x 31 columns]

# %%
GDPpC_df = GDPpC_df.drop(columns=['CountryID'])
GDPpC_df = GDPpC_df.rename(columns={'Country': 'Region'})
GDPpC_df.head()
# Out:
#         Region   1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# 0  Afghanistan    292    251    240    168    124    179    166    156    148
# 1      Albania    653    487    467    532    598    769   1033    718    821
# 2      Algeria   2397   1764   1817   1840   1500   1459   1600   1616   1592
# 3      Andorra  23886  24714  25999  20900  20542  23359  24064  23224  23908
# 4       Angola   1153   1321   1468   1030   1026    476    606    688    561
#
#    ...   2009   2010   2011   2012   2013   2014   2015   2016   2017   2018
# 0  ...    443    551    637    685    670    639    599    572    593    552
# 1  ...   4051   4046   4402   4228   4400   4567   3939   4109   4516   5224
# 2  ...   3883   4481   5456   5592   5500   5493   4178   3946   4044   4115
# 3  ...  43336  39734  41103  38393  40629  42299  36041  37223  39231  42052
# 4  ...   3123   3588   4615   5100   5255   5408   4167   3506   4096   3437
#
# [5 rows x 30 columns]

# %%
recent_GDPpC_df = GDPpC_df[['Region']]
recent_GDPpC_df['GDPpC'] = round(GDPpC_df[['2012','2013','2014',
                                           '2015','2016','2017',
                                           '2018']].mean(axis=1),1)

recent_GDPpC_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#           Region    GDPpC
# 0    Afghanistan    615.7
# 1        Albania   4426.1
# 2        Algeria   4695.4
# 3        Andorra  39409.7
# 4         Angola   4424.1
# ..           ...      ...
# 205     Viet Nam   2122.6
# 206        Yemen   1100.1
# 207       Zambia   1566.3
# 208     Zanzibar    884.4
# 209     Zimbabwe   1473.1
#
# [210 rows x 2 columns]

# %%
gender_medalled_GDPpC_df = pd.merge(
    gender_medalled_df, recent_GDPpC_df, 
    on='Region', how='left')

gender_medalled_GDPpC_df
# Out:
#                   Region  Medal_Females  Medal_Males  Medal_Total  \
# 0              Argentina            2.0         20.0         22.0
# 1              Australia           41.0         44.0         85.0
# 2                Austria            9.0         20.0         29.0
# 3             Azerbaijan            4.0         14.0         18.0
# 4                Bahrain            2.0          0.0          2.0
# ..                   ...            ...          ...          ...
# 70                 Qatar            0.0          1.0          1.0
# 71            Tajikistan            0.0          1.0          1.0
# 72              Trinidad            0.0          1.0          1.0
# 73  United Arab Emirates            0.0          1.0          1.0
# 74            Uzbekistan            0.0         13.0         13.0
#
#     Percent_Female  Percent_Male  WPS Index rank  WPS Index value    GDPpC
# 0             9.09         90.91              48            0.775  13694.3
# 1            48.24         51.76              22            0.844  60014.9
# 2            31.03         68.97               6            0.884  48222.9
# 3            22.22         77.78             123            0.650   5944.6
# 4           100.00          0.00              83            0.719  23793.9
# ..             ...           ...             ...              ...      ...
# 70            0.00        100.00              72            0.730  72035.0
# 71            0.00        100.00              96            0.701    929.7
# 72            0.00        100.00              41            0.788  18201.0
# 73            0.00        100.00              44            0.781  40966.3
# 74            0.00        100.00              89            0.710   2235.7
#
# [75 rows x 9 columns]

# %%
x_values = gender_medalled_GDPpC_df.GDPpC
y_values = gender_medalled_GDPpC_df.Medal_Total
z_values = gender_medalled_GDPpC_df.Medal_Total

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(0,(10,5))
plt.scatter(x_values, y_values, s=50, edgecolor='steelblue', alpha=.6)
plt.plot(x_values,regress_values,"r-",lw=.2)
#plt.annotate(line_eq,(.71,.7),fontsize=12,color="red", rotation=5)
#plt.annotate('USA -->',(.81,7.1),fontsize=12,color="steelblue")
#plt.annotate('Russia -->',(.72,4.0),fontsize=12,color="steelblue")
#plt.annotate('Canada -->',(.82,3.8),fontsize=12,color="steelblue")
#plt.annotate('Germany -->',(.79,3.0),fontsize=12,color="steelblue")
#plt.annotate('China -->',(.68,2.9),fontsize=12,color="steelblue")
plt.title('Medals per Country vs. GDP per Capita')
plt.xlabel('GDP per Capita ($)')
plt.ylabel('Medals per Country')
#plt.ylim(-1,10)
print(f"The correlation value (r) is: {rvalue}")
plt.show()
# Out:
# The correlation value (r) is: 0.4214673992361718

# %% [markdown]
# ## vs GDP

# %%
# Read CSV into Pandas DataFrame
raw_GDP_df = pd.read_csv('raw_data/CLEAN-GDPcurrent-USD-countries.csv')

raw_GDP_df.head()
# Out:
#    CountryID      Country                                      IndicatorName  \
# 0          4  Afghanistan                      Final consumption expenditure
# 1          4  Afghanistan  Household consumption expenditure (including N...
# 2          4  Afghanistan   General government final consumption expenditure
# 3          4  Afghanistan                            Gross capital formation
# 4          4  Afghanistan  Gross fixed capital formation (including Acqui...
#
#            1970          1971          1972          1973          1974  \
# 0  1.691109e+09  1.826664e+09  1.544444e+09  1.637778e+09  1.984444e+09
# 1  1.577102e+09  1.703519e+09  1.440325e+09  1.527366e+09  1.850662e+09
# 2  1.140071e+08  1.231456e+08  1.041196e+08  1.104117e+08  1.337824e+08
# 3  9.555556e+07  9.999998e+07  1.044445e+08  1.266666e+08  1.888889e+08
# 4  9.555556e+07  9.999998e+07  1.044445e+08  1.266666e+08  1.888889e+08
#
#            1975          1976  ...          2009          2010          2011  \
# 0  2.173333e+09  2.248889e+09  ...  1.381317e+10  1.790740e+10  1.987430e+10
# 1  2.026817e+09  2.097279e+09  ...  1.238645e+10  1.565480e+10  1.752369e+10
# 2  1.465165e+08  1.516101e+08  ...  1.426726e+09  2.252604e+09  2.350610e+09
# 3  2.311111e+08  3.488889e+08  ...  2.186826e+09  2.807688e+09  3.033178e+09
# 4  2.311111e+08  3.488889e+08  ...  2.186826e+09  2.807688e+09  3.033178e+09
#
#            2012          2013          2014          2015          2016  \
# 0  2.051016e+10  1.992941e+10  1.963399e+10  1.956615e+10  1.894331e+10
# 1  1.793411e+10  1.741045e+10  1.701266e+10  1.707584e+10  1.651919e+10
# 2  2.576049e+09  2.518965e+09  2.621337e+09  2.490307e+09  2.424112e+09
# 3  3.503714e+09  3.614753e+09  3.745089e+09  3.922627e+09  3.479986e+09
# 4  3.503714e+09  3.614753e+09  3.745089e+09  3.922627e+09  3.479986e+09
#
#            2017          2018
# 0  1.891049e+10  1.873642e+10
# 1  1.634993e+10  1.619171e+10
# 2  2.560560e+09  2.544711e+09
# 3  3.904882e+09  4.516001e+09
# 4  3.904882e+09  4.516001e+09
#
# [5 rows x 52 columns]

# %%
raw_GDP_df = raw_GDP_df.drop(columns=['CountryID'])
raw_GDP_df = raw_GDP_df.rename(columns={'Country': 'Region'})
raw_GDP_df.head(17)
# Out:
#          Region                                      IndicatorName  \
# 0   Afghanistan                      Final consumption expenditure
# 1   Afghanistan  Household consumption expenditure (including N...
# 2   Afghanistan   General government final consumption expenditure
# 3   Afghanistan                            Gross capital formation
# 4   Afghanistan  Gross fixed capital formation (including Acqui...
# 5   Afghanistan                      Exports of goods and services
# 6   Afghanistan                      Imports of goods and services
# 7   Afghanistan                       Gross Domestic Product (GDP)
# 8   Afghanistan  Agriculture, hunting, forestry, fishing (ISIC ...
# 9   Afghanistan        Mining, Manufacturing, Utilities (ISIC C-E)
# 10  Afghanistan                             Manufacturing (ISIC D)
# 11  Afghanistan                              Construction (ISIC F)
# 12  Afghanistan  Wholesale, retail trade, restaurants and hotel...
# 13  Afghanistan      Transport, storage and communication (ISIC I)
# 14  Afghanistan                        Other Activities (ISIC J-P)
# 15  Afghanistan                                  Total Value Added
# 16      Albania                      Final consumption expenditure
#
#             1970          1971          1972          1973          1974  \
# 0   1.691109e+09  1.826664e+09  1.544444e+09  1.637778e+09  1.984444e+09
# 1   1.577102e+09  1.703519e+09  1.440325e+09  1.527366e+09  1.850662e+09
# 2   1.140071e+08  1.231456e+08  1.041196e+08  1.104117e+08  1.337824e+08
# 3   9.555556e+07  9.999998e+07  1.044445e+08  1.266666e+08  1.888889e+08
# 4   9.555556e+07  9.999998e+07  1.044445e+08  1.266666e+08  1.888889e+08
# 5   1.711111e+08  2.000000e+08  2.355555e+08  2.244444e+08  3.022222e+08
# 3    2.877201e+09  3.020852e+09  3.238225e+09
# 4    1.010000e+11  1.220000e+11  1.060000e+11
# ..            ...           ...           ...
# 216           NaN           NaN           NaN
# 217           NaN           NaN           NaN
# 218  2.145266e+10  2.586814e+10  2.728285e+10
# 219  1.262100e+09  1.448096e+09  1.618001e+09
# 220  2.085087e+10  2.226353e+10  2.495747e+10
#
# [221 rows x 51 columns]

# %%
recent_GDP_df = GDP_df[['Region']]
recent_GDP_df['GDP'] = round(GDP_df[['2012','2013','2014',
                                       '2015','2016','2017',
                                       '2018']].mean(axis=1)/(10**9),3)

recent_GDP_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                         Region      GDP
# 0                  Afghanistan   21.021
# 1                      Albania   12.808
# 2                      Algeria  185.714
# 3                      Andorra    3.106
# 4                       Angola  123.286
# ..                         ...      ...
# 216  Yemen Democratic (Former)      NaN
# 217        Yugoslavia (Former)      NaN
# 218                     Zambia   24.798
# 219                   Zanzibar    1.281
# 220                   Zimbabwe   21.352
#
# [221 rows x 2 columns]

# %%
gender_medalled_GDP_df = pd.merge(
    gender_medalled_df, recent_GDP_df, 
    on='Region', how='left')

gender_medalled_GDP_df.tail()
# Out:
#                   Region  Medal_Females  Medal_Males  Medal_Total  \
# 70                 Qatar            0.0          1.0          1.0
# 71            Tajikistan            0.0          1.0          1.0
# 72              Trinidad            0.0          1.0          1.0
# 73  United Arab Emirates            0.0          1.0          1.0
# 74            Uzbekistan            0.0         13.0         13.0
#
#     Percent_Female  Percent_Male  WPS Index rank  WPS Index value      GDP
# 70             0.0         100.0              72            0.730  186.429
# 71             0.0         100.0              96            0.701    8.326
# 72             0.0         100.0              41            0.788   24.897
# 73             0.0         100.0              44            0.781  384.429
# 74             0.0         100.0              89            0.710   68.992

# %%
### Check
gender_medalled_GDP_df.loc[gender_medalled_GDP_df.GDP.isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Region, Medal_Females, Medal_Males, Medal_Total, Percent_Female, Percent_Male, WPS Index rank, WPS Index value, GDP]
# Index: []

# %%
x_values = gender_medalled_GDP_df.GDP
y_values = gender_medalled_GDP_df.Medal_Total

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(0,(10,5))
plt.scatter(x_values, y_values, s=50, edgecolor='steelblue', alpha=.6)
plt.plot(x_values.sort_values(), regress_values.sort_values(), 'r:')
plt.title('Medals per Country vs. GDP per Capita')
plt.xlabel('GDP in Billions ($)')
plt.ylabel('Medals per Country')
print(f"The correlation value (r) is: {rvalue}")
plt.show()
# Out:
# The correlation value (r) is: 0.7845933384166361

# %%
x_values = gender_medalled_GDP_df.GDP
y_values = gender_medalled_GDP_df.Medal_Total

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(0,(10,5))
plt.scatter(x_values, y_values, s=50, edgecolor='steelblue', alpha=.6)
plt.plot(x_values.sort_values(), regress_values.sort_values(), 'r:')
plt.title('Medal Count vs. GDP per Capita for each Country')
plt.xlabel('GDP in Billions ($)')
plt.ylabel('Medals per Country')
plt.xscale('log')
print(f"The correlation value (r) is: {rvalue}")
plt.show()
# Out:
# The correlation value (r) is: 0.7845933384166361

# %%
x_values = gender_medalled_GDP_df.GDP
y_values = gender_medalled_GDP_df.Medal_Total
z_values = gender_medalled_GDP_df['WPS Index value']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(0,(10,5))
plt.scatter(x_values, y_values, c=z_values, edgecolor='steelblue', alpha=.6)
plt.plot(x_values.sort_values(), regress_values.sort_values(), 'r:')
plt.title('Medal Count vs. GDP per Capita for each Country')
plt.xlabel('GDP in Billions ($)')
plt.ylabel('Medals per Country')
plt.xscale('log')
print(f"The correlation value (r) is: {rvalue}")
plt.show()
# Out:
# The correlation value (r) is: 0.7845933384166361

# %%
x_values = gender_medalled_GDP_df.GDP**(1/2)
y_values = gender_medalled_GDP_df.Medal_Total
z_values = gender_medalled_GDP_df.Medal_Total

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(0,(10,5))
plt.scatter(x_values, y_values, s=50, edgecolor='steelblue', alpha=.6)
plt.plot(x_values.sort_values(), regress_values.sort_values(), 'r:')
plt.title('Medals per Country vs. GDP per Capita')
plt.xlabel('Square Root of the GDP in Billions ($^1/2)')
plt.ylabel('Medals per Country')
#plt.xlim(-200,3000)
#plt.ylim(-5,200)

print(f"The correlation value (r) is: {rvalue}")
plt.show()
# Out:
# The correlation value (r) is: 0.8163647116153319

# %%
gender_medalled_GDP_pC_df = pd.merge(
    gender_medalled_GDP_df, recent_GDPpC_df, 
    on='Region', how='left')

gender_medalled_GDP_pC_df.tail()
# Out:
#                   Region  Medal_Females  Medal_Males  Medal_Total  \
# 70                 Qatar            0.0          1.0          1.0
# 71            Tajikistan            0.0          1.0          1.0
# 72              Trinidad            0.0          1.0          1.0
# 73  United Arab Emirates            0.0          1.0          1.0
# 74            Uzbekistan            0.0         13.0         13.0
#
#     Percent_Female  Percent_Male  WPS Index rank  WPS Index value      GDP  \
# 70             0.0         100.0              72            0.730  186.429
# 71             0.0         100.0              96            0.701    8.326
# 72             0.0         100.0              41            0.788   24.897
# 73             0.0         100.0              44            0.781  384.429
# 74             0.0         100.0              89            0.710   68.992
#
#       GDPpC
# 70  72035.0
# 71    929.7
# 72  18201.0
# 73  40966.3
# 74   2235.7

# %%
x_values = gender_medalled_GDP_pC_df.GDP
y_values = gender_medalled_GDP_pC_df.Medal_Total
z_values = gender_medalled_GDP_pC_df.GDPpC

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(0,(10,5))
plt.scatter(x_values, y_values, c=z_values**(1/2), s=100, alpha=.6)
plt.plot(x_values.sort_values(), regress_values.sort_values(), 'r:')
plt.title('Medal Count vs. GDP per Capita for each Country')
plt.xlabel('GDP in Billions ($)')
plt.ylabel('Medals per Country')
plt.xscale('log')
plt.colorbar(label='GDP per Capita')
print(f"The correlation value (r) is: {rvalue}")
plt.show()
# Out:
# The correlation value (r) is: 0.7845933384166361

# %%
coefficient = stats.pearsonr(
    gender_medalled_GDP_pC_df.GDP,gender_medalled_GDP_pC_df.Medal_Total)[0]
pvalue = stats.pearsonr(
    gender_medalled_GDP_pC_df.GDP,gender_medalled_GDP_pC_df.Medal_Total)[1]

print(f"The correlation is {round(coefficient,4)} and the p-value is {pvalue}")
# Out:
# The correlation is 0.7846 and the p-value is 8.236495577896968e-17
